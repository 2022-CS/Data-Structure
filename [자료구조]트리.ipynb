# %% [markdown]
# ## 트리

# %% [markdown]
# ### Q1. 트리란 무엇인가?

# %%
from IPython.display import Image

Image("/Users/jenny/Desktop/tree.png")

# %% [markdown]
# 노드들이 나무 가지처럼 연결된 비선형 계층적 자료구조
# 트리 내에 다른 하위 트리가 있고 그 하위 트리 안에는 또 다른 하위 트리가 있는 재귀적 자료구조

# %% [markdown]
# - 루트: 가장 상위 노드
# - 서브 트리: 루트를 제외한 나머지 노드들
# - 간선 : 각 노드를 연결하는 선
# - 차수 : 노드가 가지고 있는 자식 노드의 수
# - 레벨 : 루트의 레벨이 1이며 층을 내려갈 수록 레벨이 증가
# - 트리의 높이 : 트리의 최대 레벨

# %% [markdown]
# ### Q2. 트리와 이진트리의 차이?

# %% [markdown]
# **트리(Tree)
#
# - 그래프의 일종으로, 여러 노드가 한 노드를 가리킬 수 없는 구조이다.
#
# - 간단하게 회로가 없고, 서로 다른 두 노드를 잇는 길이 하나뿐인 그래프를 트리라고 부른다.
#
# - 트리에서 최상위 노드를 루트노드(root node)라고 한다.
#
# - 한 노드 A가 노드 B를 가리킬 때 A를 B의 부모노드(parent node), B를 A의 자식노드(chiled node)라고 한다.
#
# - 자식 노드가 없는 노드를 잎 노드(leaf node)라고 한다.
#
# - 잎 노드가 아닌 노드를 내부 노드(internal node)라고 한다.

# %% [markdown]
# **이진 트리(Binary Tree)
#
# - 노드가 최대 두 개의 자식 노드를 가지는 트리를 뜻한다.
#
# - 보통 첫 번쨰 노드를 부모 노드라고 하며 자식 노드는 왼쪽(left)와 오른쪽(right)으로 불린다.
#
# - 이진 탐색 트리와 이진 힙의 구현에 흔히 쓰인다.

# %% [markdown]
# **차이
# - 트리의 경우 자식 노드의 수가 제한이 없지만 이진 트리는 최대 2개의 자식 노드만 가질 수 있다.

# %%
Image("/Users/jenny/Desktop/binarytree.png")

# %% [markdown]
# ##

# %% [markdown]
# ### Q3. binary tree(이진트리) binary search tree(이진검색트리)의 차이점?

# %%
Image("/Users/jenny/Desktop/tree1.png")

# %% [markdown]
# https://galid1.tistory.com/176

# %% [markdown]
# ### Q4. full binary tree / complete binary tree / perfect binary tree 차이

# %% [markdown]
# ** 정 이진 트리(Full binary tree)
#
#     - 모든 노드가 0개 혹은 2개의 자식 노드를 가짐
#     - leaf 노드들을 제외한 모든 노드들이 2개의 자식노드를 가지는 이진 트리
#     - L = I + 1 (모든 leaf 노드의 개수는 internal node 의 개수 + 1)
#     - L = leaf nodes 개수, I = internal nodes 개수(leaf node 아닌 노드의 수)
#
# ** 완전 이진 트리(Complete binary tree)
#
#     - 마지막 level 을 제외한 나머지 level에 node들이 가득 차있고, 마지막 level에서 node는 가장 왼쪽 부터 채워지는 형태
#     - Complete Binary Tree 구조를 그대로 사용하여 Binary Heap 이라는 데이터 구조를 만들 수 있음(Heap)
#     - Complete Binary Tree (15개의 데이터가 저장된다면 index 0 ~ index 14 까지 채워진다) 구현에는 Array 를 사용하는 것이 일반적
#
# **포화 이진 트리(Perfect binary tree)
#
#     - 모든 internal node 가 2개의 자식 노드를 가지고 있고, 모든 leaf 노드가 같은 level 에 있음
#     - Height 가 h 인 Perfect Binary Tree 는 2h - 1 개의 노드를 가짐
#     - 위 그림의 경우 height 는 4 이고, 노드의 개수는 24 - 1 = 15 개의 노드를 가짐
#
# https://yaboong.github.io/data-structures/2018/02/10/1_binary-tree-1/

# %%
Image("/Users/jenny/Desktop/treetype.png")

# %% [markdown]
# ##

# %% [markdown]
# ### Q5. BST의 time complexity?

# %% [markdown]
# ** 이진 탐색 트리의 특징
# - 각 노드의 자식이 2개 이하
# - 각 노드의 왼쪽 자식은 부모보다 작고, 오른쪽 자식은 큼
# - 부모 노드의 왼쪽과 오른쪽 서브트리도 이진 탐색 트리
# - 검색 목적 자료구조이 → 모든 노드는 유일한 키를 갖게 됨

# %% [markdown]
# ##

# %% [markdown]
# ** BST 핵심연산:검색, 삽입, 삭제, 트리 생성, 트리 삭제

# %% [markdown]
# ####

# %% [markdown]
# ** 시간 복잡도</br>
# depth (트리의 높이) 를 h라고 표기한다면, O(h)n개의 노드를 가진다면,
#
# h = log2n 에 가까우므로, 시간 복잡도는 O(log n)
#
# 한번 실행시마다, 50%의 실행할 수도 있는 명령을 제거. 즉 50%의 실행시간을 단축시킬 수 있다는 것을 의미

# %% [markdown]
# ####

# %% [markdown]
# **장점</br>
# - 삽입,삭제 시에 올바른 위치를 찾아 곧바로(빠르게) 넣거나 뺄 수 있음
# - 최대값과 최소값을 쉽게 찾을 수 있음

# %% [markdown]
# ####

# %% [markdown]
# ** 단점</br>
# - 평균 시간 복잡도는 O(log n) 이지만, 이는 트리가 균형잡혀 있을 때의 평균 시간복잡도이며, 최악의 경우는 링크드 리스트등과 동일한 성능을 보여줌 O(n)
# - 배열의 경우에는, 삽입,삭제시에 매번 다시 정렬을 해야 만 이진 탐색이 가능해 짐
# - 편향 트리의 경우 배열보다 많은 메모리를 사용하며 데이터를 저장했지만 탐색에 필요한 시간 복잡도가 같게 되는 비효율적인 상황이 발생한다. 이를 해결하기 위해 Rebalancing 기법이 등장하였다. 균형을 잡기 위한 트리 구조의 재조정을 Rebalancing이라 한다. 이 기법을 구현한 트리에는 여러 종류가 존재하는데 그 중에서 하나가 뒤에서 살펴볼 Red-Black Tree이다.

# %% [markdown]
# ##

# %% [markdown]
# ### Q6. B-tree? 어디에 사용되는가?

# %% [markdown]
# https://velog.io/@emplam27/자료구조-그림으로-알아보는-B-Tree
#
# **b tree?</br>
# - 하나의 노드에 여러 데이터가 배치되는 트리구조
# - 한 노드에 최대 M개의 자료가 배치된다면 M차 B 트리

# %% [markdown]
# **b tree 특징?
# - 노드의 데이터 개수가 N이라면 노드의 자식 수는 N + 1
# - 각 노드의 자료는 정렬된 상태여야 함
# - 루트 노드를 제외한 모든 노드는 최소 M / 2개의 데이터를 가지고 있어야 함
# - 입력 데이터는 중복될 수 없습니다

# %% [markdown]
# ** DB에서 tree 사용</br>
# 트리의 Worse case에서 탐색 시간은 O(N)의 시간복잡도를 가진다. 하지만 Balanced Tree는 삽입, 삭제 시 노드의 높이를 일정하게 맞춰주기 때문에 최악의 경우도 O(logN)의 시간 복잡도를 가지기 때문이다.

# %% [markdown]
# ** O(1)의 해시 자료구조를 사용하지 않고 B 트리를 사용하는 이유</br>
#
# 해시를 사용하지 못하는 이유는 해시는 하나의 데이터를 탐색하는 시간이 O(1)이기 때문이다. </br>
# DB에서는 =이 아닌 >, <와 같은 부등호도 사용할 수 있습니다. 해시는 데이터가 정렬되어 있지 않기에 매우 비효율적입니다.</br>
# 그에 비해 트리는 정렬되어있기 때문에 효율적으로 데이터를 탐색할 수 있습니다.
#
# 1. 항상 정렬된 상태이기에 부등호 연산에 유리하다
# 2. 참조 포인터가 적어 빠르게 메모리 접근이 가능하다
# 3. 데이터 탐색뿐 아니라 삽입, 삭제에도 O(logN)의 시간 복잡도를 가진다

# %% [markdown]
# ##

# %% [markdown]
# ### Q7. b-tree ve b+tree?

# %%
Image("/Users/jenny/Desktop/b-tree.png")

# %% [markdown]
# **b-tree</br>
# - B-Tree는 노드가 inorder traversal에서 정렬되기 때문에 자체 균형 트리</br>
# - 노드는 두 개 이상의 자식을 가질 수 있으며 B-트리의 높이는 logM N(여기서 'M'은 트리의 차수이고 N은 노드 수. 그리고 업데이트할 때마다 높이가 자동으로 조정
# - 데이터는 왼쪽에 가장 낮은 값, 오른쪽에 가장 높은 값을 사용하여 특정 순서로 정렬</br>
# - 데이터나 키를 삽입하는 것은 이진 트리보다 복잡</br>
#
# ** B-tree 조건
# 1. 모든 리프 노드는 동일한 수준에 있어야 함
# 2. 리프 노드 위에는 빈 하위 트리가 없어야 함
# 3. 높이는 가능한 한 낮아야 함
#
#
# https://wangin9.tistory.com/entry/B-tree-B-tree

# %% [markdown]
# ####

# %%
Image("/Users/jenny/Desktop/Btree.jpeg")

# %% [markdown]
# **B+tree</br>
# B+tree는 데이터 포인터를 트리의 리프 노드에만 저장하여 인덱싱에 사용되는 단점 B-tree를 제거한다. 따라서 B+ 트리의 리프 노드 구조는 B 트리의 내부 노드 구조와 상당히 다르다.
#
# **B+tree 조건</br>
# :데이터 포인터는 리프 노드에만 존재하기 때문에 리프 노드는 액세스하기 위해 디스크 파일 블록에 대한 해당 데이터 포인터와 함께 모든 키 값을 반드시 저장

# %%
Image("/Users/jenny/Desktop/treedifference.png")

# %% [markdown]
# ##

# %% [markdown]
# ### Q8. Heap vs Binary Search Tree?

# %% [markdown]
# 힙과 이진탐색트리 모두 이진트리라는 점에서 공통점을 가지만 노드값이 다소 다르게 구성돼 있다.</br>
# 힙은 각 노드의 값이 자식노드보다 큰 반면, 이진탐색트리는 왼쪽 자식노드가 제일 작고 부모노드가 그 다음 크며 오른쪽 자식노드가 가장 큰 값을 가진다. 힙은 우선순위(키) 정렬에, 이진탐색트리는 탐색에 강점을 지닌 자료구조이다.

# %%
Image("/Users/jenny/Desktop/heapbst.png")

# %% [markdown]
# - Heap은 상하관계를 보장하는 반면, BST는 좌우관계를 보장한다.
#
# - Heap
#
#     - Heap에서는 상위 level에 존재하는 값이 하위 level에 존재하는 값보다 우선순위가 높다.
#     - 하지만 좌/우에서의 우선순위는 절대적이지 않다.
#     - 왼쪽의 값이 우선순위가 높을수도, 오른쪽의 값이 우선순위가 높을수도 있다.
#     - Heap에서는 root가 가장 우선순위가 높기 때문에 가장 작은 값을 추출하거나 가장 큰 값을 추출해야 하는 경우 사용한다.
#
# - BST
#
#     - BST에서는 왼쪽의 값이 오른쪽의 값보다 작다.
#     - 하지만 상/하에서의 값은 절대적이지 않다.
#     - 상위 level에 존재하는 값이 하위 level에 존재하는 값보다 클수도, 작을수도 있다.
#     - BST는 (평균적으로) 탐색이 O(log n), 삽입/삭제가 O(log n)에 가능하기 때문에 탐색이 빈번하게 일어나는 경우 사용한다.
#
#
# https://hyoeun-log.tistory.com/entry/자료구조-Heap과-BST의-차이점
